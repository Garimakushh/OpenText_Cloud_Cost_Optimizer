# %%
# !pip install torch transformers accelerate huggingface_hub rich
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !huggingface-cli whoami
# Out:
# ⚠️  Warning: 'huggingface-cli whoami' is deprecated. Use 'hf auth whoami' instead.
# Garima0807

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 7.80MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 27.6MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 705kB/s]
# Loading Meta-Llama model (may take several minutes)...
# config.json: 100% 654/654 [00:00<00:00, 4.59MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 17:14:50.424090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766510090.443774    1213 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766510090.448613    1213 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766510090.461250    1213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766510090.461272    1213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766510090.461276    1213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766510090.461282    1213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-23 17:14:50.465131: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 94.6MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00003-of-00004.safetensors:   0% 816k/4.92G [00:01<1:43:24, 792kB/s]
# model-00002-of-00004.safetensors:   0% 500k/5.00G [00:01<2:57:25, 470kB/s]
#
#
# model-00004-of-00004.safetensors:   1% 8.44M/1.17G [00:01<04:27, 4.34MB/s]
#
#
# model-00004-of-00004.safetensors:   2% 23.1M/1.17G [00:04<03:28, 5.48MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.13M/4.98G [00:05<6:26:32, 215kB/s]
#
# model-00003-of-00004.safetensors:   0% 2.33M/4.92G [00:05<3:17:22, 415kB/s]
# model-00002-of-00004.safetensors:   0% 1.73M/5.00G [00:06<5:19:45, 261kB/s]
#
# model-00003-of-00004.safetensors:   1% 69.4M/4.92G [00:07<06:29, 12.4MB/s]
# model-00002-of-00004.safetensors:   3% 136M/5.00G [00:07<03:08, 25.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.17M/4.98G [00:08<11:29:22, 120kB/s]
# model-00002-of-00004.safetensors:   7% 337M/5.00G [00:10<01:48, 43.0MB/s]
#
#
# model-00004-of-00004.safetensors:   8% 90.2M/1.17G [00:10<01:57, 9.17MB/s]
#
# model-00003-of-00004.safetensors:   3% 136M/4.92G [00:11<05:37, 14.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.20M/4.98G [00:14<25:05:38, 55.1kB/s]
# model-00002-of-00004.safetensors:   9% 471M/5.00G [00:14<01:59, 37.9MB/s]
#
#
# model-00004-of-00004.safetensors:  13% 157M/1.17G [00:14<01:26, 11.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.21M/4.98G [00:15<25:35:57, 54.0kB/s]
# model-00002-of-00004.safetensors:  12% 605M/5.00G [00:15<01:19, 55.0MB/s]
#
#
# model-00004-of-00004.safetensors:  19% 225M/1.17G [00:18<01:09, 13.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.23M/4.98G [00:18<39:54:15, 34.6kB/s]
#
# model-00003-of-00004.safetensors:   6% 271M/4.92G [00:19<04:48, 16.1MB/s]
#
#
# model-00004-of-00004.safetensors:  25% 292M/1.17G [00:19<00:43, 20.3MB/s]
# model-00002-of-00004.safetensors:  13% 672M/5.00G [00:19<01:59, 36.1MB/s]
#
# model-00003-of-00004.safetensors:   7% 338M/4.92G [00:19<03:25, 22.3MB/s]
#
#
# model-00004-of-00004.safetensors:  29% 336M/1.17G [00:19<00:31, 26.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.24M/4.98G [00:19<44:07:05, 31.3kB/s]
#
# model-00003-of-00004.safetensors:   8% 405M/4.92G [00:20<02:27, 30.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.25M/4.98G [00:20<45:48:23, 30.2kB/s]
# model-00002-of-00004.safetensors:  15% 740M/5.00G [00:20<01:44, 40.6MB/s]
#
# model-00003-of-00004.safetensors:  10% 472M/4.92G [00:20<01:52, 39.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.27M/4.98G [00:22<62:49:24, 22.0kB/s]
#
# model-00003-of-00004.safetensors:  11% 539M/4.92G [00:22<02:03, 35.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.28M/4.98G [00:22<56:38:46, 24.4kB/s]
#
#
# model-00004-of-00004.safetensors:  35% 404M/1.17G [00:23<00:34, 22.3MB/s]
#
# model-00003-of-00004.safetensors:  14% 673M/4.92G [00:23<01:16, 55.8MB/s]
#
#
# model-00004-of-00004.safetensors:  37% 430M/1.17G [00:24<00:32, 22.7MB/s]
#
# model-00003-of-00004.safetensors:  15% 740M/4.92G [00:24<01:13, 57.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.30M/4.98G [00:24<72:37:00, 19.0kB/s]
#
#
# model-00004-of-00004.safetensors:  43% 497M/1.17G [00:25<00:19, 33.9MB/s]
#
# model-00003-of-00004.safetensors:  16% 807M/4.92G [00:25<00:59, 68.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.31M/4.98G [00:25<73:01:57, 18.9kB/s]
#
# model-00003-of-00004.safetensors:  18% 874M/4.92G [00:25<00:52, 77.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.34M/4.98G [00:26<61:47:06, 22.4kB/s]
# model-00002-of-00004.safetensors:  16% 807M/5.00G [00:30<03:47, 18.4MB/s]
#
# model-00003-of-00004.safetensors:  19% 941M/4.92G [00:30<01:54, 34.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.36M/4.98G [00:31<125:12:18, 11.0kB/s]
# model-00002-of-00004.safetensors:  19% 941M/5.00G [00:31<02:18, 29.3MB/s]
#
#
# model-00004-of-00004.safetensors:  48% 565M/1.17G [00:31<00:30, 20.0MB/s]
#
#
# model-00004-of-00004.safetensors:  54% 632M/1.17G [00:31<00:19, 27.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.37M/4.98G [00:31<118:49:16, 11.6kB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.39M/4.98G [00:32<98:39:18, 14.0kB/s]
#
# model-00003-of-00004.safetensors:  21% 1.01G/4.92G [00:32<01:53, 34.5MB/s]
# model-00002-of-00004.safetensors:  20% 1.01G/5.00G [00:32<02:08, 31.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.40M/4.98G [00:32<94:28:04, 14.6kB/s]
#
#
# model-00004-of-00004.safetensors:  60% 699M/1.17G [00:32<00:14, 32.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.41M/4.98G [00:33<90:51:09, 15.2kB/s]
#
#
# model-00004-of-00004.safetensors:  66% 766M/1.17G [00:33<00:09, 42.6MB/s]
# model-00002-of-00004.safetensors:  23% 1.14G/5.00G [00:33<01:28, 43.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.42M/4.98G [00:33<90:29:36, 15.3kB/s]
#
#
# model-00004-of-00004.safetensors:  71% 833M/1.17G [00:33<00:06, 53.8MB/s]
#
# model-00003-of-00004.safetensors:  23% 1.14G/4.92G [00:33<01:19, 47.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.43M/4.98G [00:34<88:58:52, 15.5kB/s]
#
# model-00003-of-00004.safetensors:  25% 1.21G/4.92G [00:34<01:05, 56.3MB/s]
# model-00002-of-00004.safetensors:  24% 1.21G/5.00G [00:34<01:17, 48.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.45M/4.98G [00:35<77:02:40, 17.9kB/s]
#
# model-00003-of-00004.safetensors:  26% 1.28G/4.92G [00:35<00:58, 62.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.48M/4.98G [00:35<43:59:20, 31.4kB/s]
#
#
# model-00004-of-00004.safetensors:  77% 900M/1.17G [00:35<00:05, 48.1MB/s]
# model-00002-of-00004.safetensors:  26% 1.28G/5.00G [00:35<01:11, 51.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.49M/4.98G [00:36<52:57:16, 26.1kB/s]
#
# model-00003-of-00004.safetensors:  27% 1.34G/4.92G [00:36<00:57, 62.2MB/s]
# model-00002-of-00004.safetensors:  27% 1.35G/5.00G [00:36<01:05, 55.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.51M/4.98G [00:41<160:16:51, 8.62kB/s]
#
#
# model-00004-of-00004.safetensors:  83% 967M/1.17G [00:41<00:08, 25.1MB/s]
#
# model-00003-of-00004.safetensors:  29% 1.41G/4.92G [00:41<01:53, 31.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.53M/4.98G [00:41<111:40:09, 12.4kB/s]
#
#
# model-00004-of-00004.safetensors:  89% 1.03G/1.17G [00:47<00:07, 18.1MB/s]
# model-00002-of-00004.safetensors:  28% 1.41G/5.00G [00:47<03:18, 18.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.56M/4.98G [00:47<179:31:03, 7.70kB/s]
# model-00002-of-00004.safetensors:  30% 1.48G/5.00G [00:47<02:25, 24.2MB/s]
#
#
# model-00004-of-00004.safetensors:  94% 1.10G/1.17G [00:48<00:02, 23.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.58M/4.98G [00:48<143:10:51, 9.65kB/s]
#
# model-00003-of-00004.safetensors:  30% 1.48G/4.92G [00:48<03:03, 18.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.59M/4.98G [00:48<135:23:18, 10.2kB/s]
#
# model-00003-of-00004.safetensors:  33% 1.61G/4.92G [00:48<01:40, 32.8MB/s]
# model-00002-of-00004.safetensors:  31% 1.55G/5.00G [00:49<02:10, 26.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.60M/4.98G [00:50<158:50:54, 8.70kB/s]
#
# model-00003-of-00004.safetensors:  34% 1.68G/4.92G [00:50<01:40, 32.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.61M/4.98G [00:51<143:42:21, 9.62kB/s]
#
# model-00003-of-00004.safetensors:  36% 1.75G/4.92G [00:51<01:20, 39.2MB/s]
# model-00002-of-00004.safetensors:  32% 1.61G/5.00G [00:51<02:02, 27.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.62M/4.98G [00:51<110:18:09, 12.5kB/s]
#
# model-00003-of-00004.safetensors:  37% 1.81G/4.92G [00:52<01:03, 48.8MB/s]
# model-00002-of-00004.safetensors:  34% 1.68G/5.00G [00:52<01:34, 35.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.64M/4.98G [00:53<130:35:34, 10.6kB/s]
#
# model-00003-of-00004.safetensors:  38% 1.88G/4.92G [00:53<01:08, 44.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.65M/4.98G [00:54<129:04:19, 10.7kB/s]
# model-00002-of-00004.safetensors:  35% 1.75G/5.00G [00:57<02:20, 23.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 1.67M/4.98G [00:57<162:02:40, 8.53kB/s]
#
# model-00003-of-00004.safetensors:  41% 2.02G/4.92G [00:57<01:14, 38.7MB/s]
# model-00002-of-00004.safetensors:  38% 1.88G/5.00G [00:58<01:18, 39.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   1% 68.7M/4.98G [00:58<05:56, 13.8MB/s]
#
# model-00003-of-00004.safetensors:  42% 2.08G/4.92G [00:58<01:01, 46.1MB/s]
#
#
# model-00004-of-00004.safetensors:  94% 1.10G/1.17G [01:00<00:02, 23.9MB/s]
#
# model-00003-of-00004.safetensors:  44% 2.15G/4.92G [01:01<01:16, 36.1MB/s]
# model-00002-of-00004.safetensors:  39% 1.95G/5.00G [01:01<01:36, 31.5MB/s]
#
#
# model-00004-of-00004.safetensors: 100% 1.17G/1.17G [01:02<00:00, 18.8MB/s]
#
#
#
#
# model-00001-of-00004.safetensors:   3% 136M/4.98G [01:02<05:07, 15.8MB/s]
# model-00002-of-00004.safetensors:  42% 2.08G/5.00G
1MB/s]
#
#
#
# model-00001-of-00004.safetensors:   9% 453M/4.98G [02:04<03:52, 19.5MB/s]
#
# model-00003-of-00004.safetensors:  97% 4.78G/4.92G [02:04<00:03, 40.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:  10% 520M/4.98G [02:04<02:24, 30.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  12% 587M/4.98G [02:07<02:25, 30.2MB/s]
# model-00002-of-00004.safetensors:  97% 4.87G/5.00G [02:07<00:03, 40.3MB/s]
#
# model-00003-of-00004.safetensors:  99% 4.85G/4.92G [02:07<00:02, 32.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:  12% 598M/4.98G [02:07<02:28, 29.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  15% 722M/4.98G [02:08<01:09, 61.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  15% 759M/4.98G [02:08<00:58, 72.0MB/s]
#
# model-00003-of-00004.safetensors: 100% 4.92G/4.92G [02:08<00:00, 38.3MB/s]
#
#
#
#
# model-00001-of-00004.safetensors:  17% 826M/4.98G [02:08<00:47, 87.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  18% 893M/4.98G [02:08<00:36, 111MB/s]
#
#
#
# model-00001-of-00004.safetensors:  19% 960M/4.98G [02:09<00:29, 135MB/s]
#
#
#
# model-00001-of-00004.safetensors:  21% 1.03G/4.98G [02:09<00:24, 162MB/s]
#
#
#
# model-00001-of-00004.safetensors:  22% 1.09G/4.98G [02:09<00:23, 164MB/s]
#
#
#
# model-00001-of-00004.safetensors:  25% 1.23G/4.98G [02:10<00:16, 228MB/s]
#
#
#
# model-00001-of-00004.safetensors:  26% 1.30G/4.98G [02:10<00:14, 248MB/s]
#
#
#
# model-00001-of-00004.safetensors:  28% 1.38G/4.98G [02:11<00:19, 187MB/s]
# model-00002-of-00004.safetensors:  99% 4.93G/5.00G [02:11<00:02, 27.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  29% 1.45G/4.98G [02:11<00:22, 157MB/s]
#
#
#
# model-00001-of-00004.safetensors:  30% 1.52G/4.98G [02:11<00:17, 196MB/s]
#
#
#
# model-00001-of-00004.safetensors:  32% 1.58G/4.98G [02:12<00:17, 191MB/s]
#
#
#
# model-00001-of-00004.safetensors:  33% 1.65G/4.98G [02:12<00:13, 238MB/s]
#
#
#
# model-00001-of-00004.safetensors:  35% 1.72G/4.98G [02:12<00:13, 234MB/s]
#
#
#
# model-00001-of-00004.safetensors:  36% 1.78G/4.98G [02:13<00:19, 167MB/s]
#
#
#
# model-00001-of-00004.safetensors:  37% 1.83G/4.98G [02:13<00:19, 161MB/s]
#
#
#
# model-00001-of-00004.safetensors:  38% 1.90G/4.98G [02:13<00:15, 195MB/s]
#
#
#
# model-00001-of-00004.safetensors:  40% 1.97G/4.98G [02:15<00:37, 81.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:  41% 2.04G/4.98G [02:16<00:33, 88.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  42% 2.10G/4.98G [02:16<00:28, 99.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  43% 2.14G/4.98G [02:16<00:25, 110MB/s]
#
#
#
# model-00001-of-00004.safetensors:  44% 2.20G/4.98G [02:17<00:23, 118MB/s]
#
#
#
# model-00001-of-00004.safetensors:  46% 2.27G/4.98G [02:17<00:17, 158MB/s]
#
#
#
# model-00001-of-00004.safetensors:  47% 2.35G/4.98G [02:18<00:15, 167MB/s]
#
#
#
# model-00001-of-00004.safetensors:  48% 2.39G/4.98G [02:18<00:14, 181MB/s]
#
#
#
# model-00001-of-00004.safetensors:  49% 2.46G/4.98G [02:18<00:16, 156MB/s]
#
#
#
# model-00001-of-00004.safetensors:  51% 2.53G/4.98G [02:19<00:15, 160MB/s]
#
#
#
# model-00001-of-00004.safetensors:  52% 2.59G/4.98G [02:20<00:24, 98.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:  53% 2.65G/4.98G [02:20<00:19, 120MB/s]
#
#
#
# model-00001-of-00004.safetensors:  55% 2.72G/4.98G [02:21<00:21, 104MB/s]
#
#
#
# model-00001-of-00004.safetensors:  56% 2.79G/4.98G [02:21<00:15, 137MB/s]
#
#
#
# model-00001-of-00004.safetensors:  58% 2.88G/4.98G [02:21<00:10, 192MB/s]
#
#
#
# model-00001-of-00004.safetensors:  59% 2.94G/4.98G [02:21<00:09, 222MB/s]
#
#
#
# model-00001-of-00004.safetensors:  61% 3.03G/4.98G [02:22<00:10, 178MB/s]
#
#
#
# model-00001-of-00004.safetensors:  62% 3.10G/4.98G [02:22<00:08, 210MB/s]
#
#
#
# model-00001-of-00004.safetensors:  64% 3.16G/4.98G [02:23<00:08, 224MB/s]
#
#
#
# model-00001-of-00004.safetensors:  65% 3.23G/4.98G [02:23<00:09, 178MB/s]
#
#
#
# model-00001-of-00004.safetensors:  66% 3.30G/4.98G [02:25<00:21, 76.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  68% 3.36G/4.98G [02:25<00:15, 103MB/s]
#
#
#
# model-00001-of-00004.safetensors:  69% 3.43G/4.98G [02:26<00:12, 127MB/s]
#
#
#
# model-00001-of-00004.safetensors:  70% 3.50G/4.98G [02:26<00:09, 150MB/s]
#
#
#
# model-00001-of-00004.safetensors:  71% 3.53G/4.98G [02:26<00:09, 152MB/s]
# model-00002-of-00004.safetensors: 100% 5.00G/5.00G [02:26<00:00, 34.1MB/s]
#
#
#
#
# model-00001-of-00004.safetensors:  72% 3.60G/4.98G [02:26<00:09, 145MB/s]
#
#
#
# model-00001-of-00004.safetensors:  74% 3.67G/4.98G [02:27<00:06, 193MB/s]
#
#
#
# model-00001-of-00004.safetensors:  75% 3.72G/4.98G [02:27<00:06, 206MB/s]
#
#
#
# model-00001-of-00004.safetensors:  76% 3.79G/4.98G [02:27<00:05, 211MB/s]
#
#
#
# model-00001-of-00004.safetensors:  77% 3.85G/4.98G [02:27<00:05, 221MB/s]
#
#
#
# model-00001-of-00004.safetensors:  79% 3.92G/4.98G [02:28<00:04, 219MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80% 3.99G/4.98G [02:28<00:04, 207MB/s]
#
#
#
# model-00001-of-00004.safetensors:  81% 4.05G/4.98G [02:28<00:03, 253MB/s]
#
#
#
# model-00001-of-00004.safetensors:  83% 4.12G/4.98G [02:29<00:04, 205MB/s]
#
#
#
# model-00001-of-00004.safetensors:  84% 4.19G/4.98G [02:29<00:03, 259MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86% 4.26G/4.98G [02:29<00:02, 292MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87% 4.31G/4.98G [02:29<00:02, 292MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88% 4.38G/4.98G [02:29<00:02, 264MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89% 4.45G/4.98G [02:30<00:03, 174MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92% 4.58G/4.98G [02:31<00:01, 223MB/s]
#
#
#
# model-00001-of-00004.safetensors:  93% 4.65G/4.98G [02:31<00:01, 246MB/s]
#
#
#
# model-00001-of-00004.safetensors:  95% 4.71G/4.98G [02:31<00:01, 266MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96% 4.78G/4.98G [02:31<00:00, 305MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97% 4.84G/4.98G [02:31<00:00, 325MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99% 4.91G/4.98G [02:31<00:00, 298MB/s]
#
#
#
# model-00001-of-00004.safetensors: 100% 4.98G/4.98G [02:32<00:00, 32.7MB/s]
# Fetching 4 files: 100% 4/4 [02:32<00:00, 38.13s/it]
# Loading checkpoint shards: 100% 4/4 [01:00<00:00, 15.18s/it]
# generation_config.json: 100% 187/187 [00:00<00:00, 1.51MB/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Meta-Llama model loaded successfully
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 1
#
# Enter description:
# We are building a food delivery app for 10,000 users per month.Budget: ₹50,000 per month.Tech stack: Node.js backend, PostgreSQL database, object storage for images, monitoring, andbasic analytics.Non-functional requirements: scalability, cost efficiency, uptime monitoring.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ✔ Project profile generated
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 2
# Only 9 billing records generated File saved successfully.
# ✔ Billing data generated
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 3
# ✔ Cost optimization report generated successfully.
# ✔ Cost analysis completed
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 4
# {
#   "project_name": "Food Delivery App",
#   "analysis": {
#     "total_monthly_cost_inr": 13500,
#     "budget_inr": 50000,
#     "budget_variance_inr": 36500,
#     "is_over_budget": true,
#     "service_costs": {
#       "RDS": 330,
#       "Object Storage": 1050,
#       "Load Balancer": 110,
#       "Monitoring": 220,
#       "EC2": 800
#     },
#     "high_cost_services": {
#       "Object Storage": 1050
#     }
#   },
#   "recommendations": [
#     {
#       "title": "Migrate Object Storage to Azure Blob Storage",
#       "service": "Storage",
#       "current_cost": 1050,
#       "potential_savings": 300,
#       "recommendation_type": "Migration",
#       "description": "Migrate object storage to Azure Blob Storage to reduce
# costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "Azure"
#       ]
#     },
#     {
#       "title": "Rightsize EC2 Instances",
#       "service": "EC2",
#       "current_cost": 800,
#       "potential_savings": 200,
#       "recommendation_type": "Rightsizing",
#       "description": "Rightsize EC2 instances to reduce costs",
#       "implementation_effort": "low",
#       "risk_level": "low",
#       "cloud_providers": [
#         "AWS"
#       ]
#     },
#     {
#       "title": "Use Open-Source Load Balancer",
#       "service": "Load Balancer",
#       "current_cost": 110,
#       "potential_savings": 50,
#       "recommendation_type": "Open-Source",
#       "description": "Use open-source load balancer to reduce costs",
#       "implementation_effort": "low",
#       "risk_level": "low",
#       "cloud_providers": [
#         "OpenSource"
#       ]
#     },
#     {
#       "title": "Monitor and Optimize RDS Instance",
#       "service": "RDS",
#       "current_cost": 330,
#       "potential_savings": 100,
#       "recommendation_type": "Optimization",
#       "description": "Monitor and optimize RDS instance to reduce costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "AWS"
#       ]
#     },
#     {
#       "title": "Use GCP Cloud Storage for Object Storage",
#       "service": "Storage",
#       "current_cost": 1050,
#       "potential_savings": 250,
#       "recommendation_type": "Migration",
#       "description": "Use GCP Cloud Storage for object storage to reduce costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "GCP"
#       ]
#     },
#     {
#       "title": "Use Azure Database for PostgreSQL",
#       "service": "Database",
#       "current_cost": 330,
#       "potential_savings": 150,
#       "recommendation_type": "Migration",
#       "description": "Use Azure Database for PostgreSQL to reduce costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "Azure"
#       ]
#     },
#     {
#       "title": "Use Open-Source Monitoring Tool",
#       "service": "Monitoring",
#       "current_cost": 220,
#       "potential_savings": 50,
#       "recommendation_type": "Open-Source",
#       "description": "Use open-source monitoring tool to reduce costs",
#       "implementation_effort": "low",
#       "risk_level": "low",
#       "cloud_providers": [
#         "OpenSource"
#       ]
#     },
#     {
#       "title": "Use AWS Lambda for Serverless Computing",
#       "service": "Compute",
#       "current_cost": 0,
#       "potential_savings": 200,
#       "recommendation_type": "Serverless",
#       "description": "Use AWS Lambda for serverless computing to reduce costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "AWS"
#       ]
#     },
#     {
#       "title": "Use Azure Functions for Serverless Computing",
#       "service": "Compute",
#       "current_cost": 0,
#       "potential_savings": 200,
#       "recommendation_type": "Serverless",
#       "description": "Use Azure Functions for serverless computing to reduce
# costs",
#       "implementation_effort": "medium",
#       "risk_level": "medium",
#       "cloud_providers": [
#         "Azure"
#       ]
#     }
#   ],
#   "summary": {
#     "total_potential_savings": 2150,
#     "savings_percentage": 43.0,
#     "recommendations_count": 9
#   }
# }
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 5
# ✔ HTML report exported
#
# Cloud Cost Optimizer
# 1. Enter project description
# 2. Generate synthetic billing data
# 3. Run cost analysis & recommendations
# 4. View cost optimization report
# 5. Export HTML report
# 6. Exit
# Choose: 6
