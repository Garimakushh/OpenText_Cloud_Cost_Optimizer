# %%
# !pip install torch transformers accelerate huggingface_hub rich

# %%
from huggingface_hub import login

login()

# %%
# !huggingface-cli whoami
# Out:
# ⚠️  Warning: 'huggingface-cli whoami' is deprecated. Use 'hf auth whoami' instead.
# Garima0807

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 7.78MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:01<00:00, 5.25MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 639kB/s]
# 🔄 Loading Meta-Llama model (first time may take several minutes)...
# config.json: 100% 654/654 [00:00<00:00, 6.23MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 07:16:02.578172: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766474162.598143    2253 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 8.15MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 20.6MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 549kB/s]
# 🔄 Loading Meta-Llama model (this may take several minutes)...
# config.json: 100% 654/654 [00:00<00:00, 5.45MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 07:55:07.710703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766476507.730658     971 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# 🔄 Loading Meta-Llama model (this may take several minutes)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 08:25:20.194627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766478320.214549    8538 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766478320.219545    8538 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766478320.232753    8538 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# 🔄 Loading Meta-Llama model (this may take several minutes)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 08:57:16.704108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766480236.724615   16617 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766480236.729623   16617 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766480236.742242   16617 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# 🔄 Loading Meta-Llama model (this may take several minutes)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 09:35:11.686194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766482511.706727   26142 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766482511.711842   26142 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766482511.725191   26142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py
# Out:
# 🔄 Loading Meta-Llama tokenizer...
# 🔄 Loading Meta-Llama model (this may take several minutes)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-23 11:09:46.421573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766488186.442191   49984 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766488186.447259   49984 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766488186.460409   49984 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
